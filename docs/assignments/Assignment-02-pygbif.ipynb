# %% [markdown]
# # Assignment 02: Fetching Occurrence Records With pygbif
#
# ## BIO597 Spatial Analysis of Biodiversity
#
# This assignment gives you more practice with the workflow from Lab 02.
#
# You will use `pygbif` to search GBIF for several snake species, download a small number of occurrence records, convert those records to `GeoDataFrame` objects, and make simple maps and summaries.
#
# Some cells are partly filled in. You should fill in the missing pieces and run the notebook from top to bottom.
#
# Remember, learning to code is often about learning how to strategically copy, paste, and modify. Look back at Lab 02 when you need a model.

# %% [markdown]
# ## Species for this assignment
#
# Use these species:
#
# * *Storeria dekayi*
# * *Agkistrodon contortrix*
# * *Pantherophis guttatus*
# * one additional snake species of your choice
#
# For each species, we will ask GBIF for georeferenced records so the results can be mapped.

# %% [markdown]
# ## 1. Import packages
#
# Import the same packages used in Lab 02.
#
# `species` is used for taxonomic name searches. `occ` is used for occurrence record searches.

# %%
from pygbif import species
from pygbif import occurrences as occ

import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## 2. Search for possible name matches
#
# Use `species.name_suggest()` to search for *Storeria dekayi*.
#
# Fill in the species name. Then inspect the first result.

# %%
dekayi_suggestions = species.name_suggest(q="Storeria dekay")
# dekayi_suggestions will have a list of dictionaries
# select the first element of this list here and save it as a new variable called `dekayi_match`
dekayi_match = dekayi_suggestions[0]
print(dekayi_match)
# Out:
# {'key': 9056579, 'nameKey': 10782717, 'kingdom': 'Animalia', 'phylum': 'Chordata', 'family': 'Colubridae', 'genus': 'Storeria', 'species': 'Storeria dekayi', 'kingdomKey': 1, 'phylumKey': 44, 'classKey': 11592253, 'familyKey': 6172, 'genusKey': 9213370, 'speciesKey': 9056579, 'parent': 'Storeria', 'parentKey': 9213370, 'nubKey': 9056579, 'scientificName': 'Storeria dekayi (Holbrook, 1839)', 'canonicalName': 'Storeria dekayi', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'synonym': False, 'higherClassificationMap': {'1': 'Animalia', '44': 'Chordata', '11592253': 'Squamata', '6172': 'Colubridae', '9213370': 'Storeria'}, 'class': 'Squamata'}

# %% [markdown]
# ## 3. Save the taxon key
#
# Pull the `speciesKey` out of the match result and save it as `dekayi_key`.

# %%
dekayi_key = dekayi_match["speciesKey"]
dekayi_key
# Out:
# 9056579

# %% [markdown]
# ## 4. Count records before downloading
#
# Use `occ.count()` to count georeferenced GBIF records for *Storeria dekayi*.
#
# This count tells you how many records GBIF has that match your search, not how many you will download in this assignment.

# %%
dekayi_count = occ.count(
    taxonKey=dekayi_key,
    isGeoreferenced=True,
)

dekayi_count
# Out:
# 49473

# %% [markdown]
# ## 5. Determine how many _total_ records there are for S. dekayi
#
# ## 5. Determine how many _total_ records there are for S. dekayi
#
# The `isGeoreferenced` parameter determines whether occurrences with latlongs are returned.
# Make a copy of the call to `occ.count()` as above, but change the `True` to `False`, which
# will return only occurrences **without** latlongs. Capture the results in a new variable
# called `dekayi_nolatlong_count` and then add this to `dekayi_count` from the previous cell
# to get the total number of records.

# %%
# How many total S. Dekayi records are there? There are 56,546

dekayi_nolatlong_count = occ.count(
    taxonKey=dekayi_key,
    isGeoreferenced=False,
)

dekayi_nolatlong_count
print(dekayi_nolatlong_count + dekayi_count)
# Out:
# 56546

# %% [markdown]
# ## 6. Fetch up to 100 records
#
# Use `occ.search()` to fetch occurrence records for *Storeria dekayi*.
#
# Keep `limit=100`. Do not request more than 100 records for a species in this assignment.

# %%
dekayi_records = occ.search(
    speciesKey= dekayi_key,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)

dekayi_records.keys()
# Out:
# dict_keys(['offset', 'limit', 'endOfRecords', 'count', 'results', 'facets'])

# %% [markdown]
# ## 7. Turn the records into a table
#
# The occurrence records are stored in the "results" key of the `dekayi_records` dictionary. Convert that list of records to a pandas DataFrame.

# %%
dekayi_df = pd.DataFrame(dekayi_records["results"])
dekayi_df.head()
# Out:
#           key                            datasetKey  \
# 0  5938064620  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  5938201753  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  5938457152  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  5938490464  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  5938606080  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                        publishingOrgKey   datasetCategory  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 2  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 3  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 4  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
#
#                         installationKey                hostingOrganizationKey  \
# 0  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 1  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 2  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 3  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 4  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
#
#   publishingCountry     protocol                    lastCrawled  \
# 0                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 1                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 2                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 3                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 4                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
#
#                       lastParsed  ...       eventTime identificationID  \
# 0  2026-09-11T05:22:11.912+00:00  ...  16:48:33-06:00        745332273
# 1  2026-09-11T05:48:03.041+00:00  ...  14:41:00-06:00        746093157
# 2  2026-09-11T05:36:08.412+00:00  ...  04:52:51-06:00        745694353
# 3  2026-09-11T05:51:42.840+00:00  ...  14:00:00-05:00        746922821
# 4  2026-09-11T05:22:15.726+00:00  ...  11:27:14-06:00        745678895
#
#              occurrenceRemarks  \
# 0                          NaN
# 1      Body about 0.5 cm wide.
# 2                          NaN
# 3  First snake of the year !!!
# 4                          NaN
#
#                                  informationWithheld projectId  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  Coordinate uncertainty increased to 28734m at ...       NaN
# 4                                                NaN       NaN
#
#    dynamicProperties  vitality  lifeStage  identificationRemarks  sex
# 0                NaN       NaN        NaN                    NaN  NaN
# 1                NaN       NaN        NaN                    NaN  NaN
# 2                NaN       NaN        NaN                    NaN  NaN
# 3                NaN       NaN        NaN                    NaN  NaN
# 4                NaN       NaN        NaN                    NaN  NaN
#
# [5 rows x 97 columns]

# %% [markdown]
# ## 8. Keep a small set of useful columns
#
# Keep the columns needed for a map and a few simple summaries.
#
# Fill in the latitude column name.

# %%
dekayi_small = dekayi_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]
]

dekayi_small.head()
# Out:
#           key                    scientificName  decimalLongitude  \
# 0  5938064620  Storeria dekayi (Holbrook, 1839)        -97.122430
# 1  5938201753  Storeria dekayi (Holbrook, 1839)        -92.908814
# 2  5938457152  Storeria dekayi (Holbrook, 1839)        -86.721496
# 3  5938490464  Storeria dekayi (Holbrook, 1839)        -80.744301
# 4  5938606080  Storeria dekayi (Holbrook, 1839)        -97.508688
#
#    decimalLatitude  year      basisOfRecord countryCode
# 0        33.241408  2026  HUMAN_OBSERVATION          US
# 1        34.619900  2026  HUMAN_OBSERVATION          US
# 2        33.458035  2026  HUMAN_OBSERVATION          US
# 3        35.172939  2026  HUMAN_OBSERVATION          US
# 4        35.238997  2026  HUMAN_OBSERVATION          US

# %% [markdown]
# ## 9. Convert the table to a GeoDataFrame
#
# Use the longitude and latitude columns to create point geometry. This is the same idea as Lab 01 and Lab 02.

# %%
dekayi_gdf = gpd.GeoDataFrame(
    dekayi_small,
    geometry=gpd.points_from_xy(dekayi_small["decimalLongitude"], dekayi_small["decimalLatitude"]),
    crs="EPSG:4326",
)

dekayi_gdf["Species"] = "Storeria dekayi"
dekayi_gdf.head()
# Out:
#           key                    scientificName  decimalLongitude  \
# 0  5938064620  Storeria dekayi (Holbrook, 1839)        -97.122430
# 1  5938201753  Storeria dekayi (Holbrook, 1839)        -92.908814
# 2  5938457152  Storeria dekayi (Holbrook, 1839)        -86.721496
# 3  5938490464  Storeria dekayi (Holbrook, 1839)        -80.744301
# 4  5938606080  Storeria dekayi (Holbrook, 1839)        -97.508688
#
#    decimalLatitude  year      basisOfRecord countryCode  \
# 0        33.241408  2026  HUMAN_OBSERVATION          US
# 1        34.619900  2026  HUMAN_OBSERVATION          US
# 2        33.458035  2026  HUMAN_OBSERVATION          US
# 3        35.172939  2026  HUMAN_OBSERVATION          US
# 4        35.238997  2026  HUMAN_OBSERVATION          US
#
#                      geometry          Species
# 0  POINT (-97.12243 33.24141)  Storeria dekayi
# 1   POINT (-92.90881 34.6199)  Storeria dekayi
# 2   POINT (-86.7215 33.45804)  Storeria dekayi
# 3   POINT (-80.7443 35.17294)  Storeria dekayi
# 4    POINT (-97.50869 35.239)  Storeria dekayi

# %% [markdown]
# ## 10. Map *Storeria dekayi*
#
# Make an interactive map of the *Storeria dekayi* records.

# %%
dekayi_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60c4c2246b7292d57827a86743819abd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60c4c2246b7292d57827a86743819abd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60c4c2246b7292d57827a86743819abd = L.map(
#                 &quot;map_60c4c2246b7292d57827a86743819abd&quot;,
#                 {
#                     center: [33.9734105, -86.7033295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_60c4c2246b7292d57827a86743819abd);
#
#
#
#
#
#             var tile_layer_428fbcab24668e5ba30473e0625cd60a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_428fbcab24668e5ba30473e0625cd60a.addTo(map_60c4c2246b7292d57827a86743819abd);
#
#
#             map_60c4c2246b7292d57827a86743819abd.fitBounds(
#                 [[25.771463, -98.225659], [42.175358, -75.181]],
#                 {}
#             );
#
#
#         function geo_json_41c1c219dff7ef025eafafd682f95cb6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_41c1c219dff7ef025eafafd682f95cb6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_41c1c219dff7ef025eafafd682f95cb6_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_41c1c219dff7ef025eafafd682f95cb6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_41c1c219dff7ef025eafafd682f95cb6_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_41c1c219dff7ef025eafafd682f95cb6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_41c1c219dff7ef025eafafd682f95cb6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_41c1c219dff7ef025eafafd682f95cb6 = L.geoJson(null, {
#                 onEachFeature: geo_json_41c1c219dff7ef025eafafd682f95cb6_onEachFeature,
#
#                 style: geo_json_41c1c219dff7ef025eafafd682f95cb6_styler,
#                 pointToLayer: geo_json_41c1c219dff7ef025eafafd682f95cb6_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_41c1c219dff7ef025eafafd682f95cb6_add (data) {
#             geo_json_41c1c219dff7ef025eafafd682f95cb6
#                 .addData(data);
#         }
#             geo_json_41c1c219dff7ef025eafafd682f95cb6_add({&quot;bbox&quot;: [-98.225659, 25.771463, -75.181, 42.175358], &quot;features&quot;: [{&quot;bbox&quot;: [-97.12243, 33.241408, -97.12243, 33.241408], &quot;geometry&quot;: {&quot;coordinates&quot;: [-97.12243, 33.241408], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Storeria dekayi&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;decimalLatitude

# %% [markdown]
# ## 11. Repeat the workflow for *Agkistrodon contortrix*
#
# Now repeat the same steps for eastern copperhead, *Agkistrodon contortrix*.
#
# This cell should get the name suggestions and save the speciesKey.

# %%
contortrix_suggestions = species.name_suggest(q="Agkistrodon contortrix")
contortrix_suggestions
# Select the first element from the `contortrix_suggestions` list
contortrix_match = contortrix_suggestions[0]
# Get the `speciesKey`
contortrix_key = contortrix_match["speciesKey"]

contortrix_key
# Out:
# 9215881

# %% [markdown]
# ## 13. Fetch and map *Agkistrodon contortrix*
#
# Write code to fetch up to 100 records with coordinates, convert them to a table, convert that table to a GeoDataFrame, add a `Species` column, and map the result.
#
# Use the same variable names shown in the comments. In `occ.search()`, use `hasCoordinate=True` and `hasGeospatialIssue=False`.
#
# # Create contortrix_records with occ.search().
#
# # Create contortrix_df from contortrix_records["results"].
#
# # Create contortrix_small with the columns you want to keep.
#
# # Create contortrix_gdf with gpd.GeoDataFrame().
#
# # Add a Species column with the name Agkistrodon contortrix.
#
# # Map contortrix_gdf with .explore().

# %%
contortrix_records = occ.search(
    speciesKey= contortrix_key,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)
contortrix_df = pd.DataFrame(contortrix_records["results"])
contortrix_small = contortrix_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]]

contortrix_gdf = gpd.GeoDataFrame(
    contortrix_small,
    geometry=gpd.points_from_xy(contortrix_small["decimalLongitude"], contortrix_small["decimalLatitude"]),
    crs="EPSG:4326",
)
contortrix_gdf["Species"] = "Agkistrodon contortrix"
contortrix_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24d6784b97cdecbb7b6b298cf26c5ed8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24d6784b97cdecbb7b6b298cf26c5ed8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24d6784b97cdecbb7b6b298cf26c5ed8 = L.map(
#                 &quot;map_24d6784b97cdecbb7b6b298cf26c5ed8&quot;,
#                 {
#                     center: [34.2329345, -86.462903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_24d6784b97cdecbb7b6b298cf26c5ed8);
#
#
#
#
#
#             var tile_layer_83a92602d125edc2ceecfdb341d45564 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83a92602d125edc2ceecfdb341d45564.addTo(map_24d6784b97cdecbb7b6b298cf26c5ed8);
#
#
#             map_24d6784b97cdecbb7b6b298cf26c5ed8.fitBounds(
#                 [[29.044931, -96.907489], [39.420938, -76.018317]],
#                 {}
#             );
#
#
#         function geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92 = L.geoJson(null, {
#                 onEachFeature: geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_onEachFeature,
#
#                 style: geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_styler,
#                 pointToLayer: geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_add (data) {
#             geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92
#                 .addData(data);
#         }
#             geo_json_03a5e1b107617c4d6ae2d67a6c0a7a92_add({&quot;bbox&quot;: [-96.907489, 29.044931, -76.018317, 39.420938], &quot;features&quot;: [{&quot;bbox&quot;: [-95.389135, 34.95654, -95.389135, 34.95654], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.389135, 34.95654], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Agkistrodon contortrix&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;dec

# %% [markdown]
# ## 14. Repeat the workflow for *Pantherophis guttatus*
#
# This time you will do a little more on your own.
#
# First, use `species.name_suggest()` to get the `speciesKey` for *Pantherophis guttatus*.

# %%
# Write your code here.
Pantherophis_suggestions = species.name_suggest(q="Pantherophis guttatus")
Pantherophis_suggestions
# Select the first element from the `contortrix_suggestions` list
Pantherophis_match = Pantherophis_suggestions[0]
# Get the `speciesKey`
Pantherophis_key = Pantherophis_match["speciesKey"]

Pantherophis_key
# Out:
# 2455615

# %% [markdown]
# ## 16. Fetch and map *Pantherophis guttatus*
#
# Fetch up to 100 georeferenced records and convert them to a GeoDataFrame.
#
# Keep the cell simple. It is fine to copy and modify code from earlier cells.

# %%
# Write your code here.
Pantherophis_records = occ.search(
    speciesKey= Pantherophis_key,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)
Pantherophis_df = pd.DataFrame(Pantherophis_records["results"])
Pantherophis_small = Pantherophis_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]]

Pantherophis_gdf = gpd.GeoDataFrame(
    Pantherophis_small,
    geometry=gpd.points_from_xy(contortrix_small["decimalLongitude"], contortrix_small["decimalLatitude"]),
    crs="EPSG:4326",
)
Pantherophis_gdf["Species"] = "Pantherophis guttatus"

Pantherophis_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aede565fe4ca001472116df3dff3dbec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aede565fe4ca001472116df3dff3dbec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aede565fe4ca001472116df3dff3dbec = L.map(
#                 &quot;map_aede565fe4ca001472116df3dff3dbec&quot;,
#                 {
#                     center: [34.2329345, -86.462903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_aede565fe4ca001472116df3dff3dbec);
#
#
#
#
#
#             var tile_layer_b4a37b8a446de7dff1c61f08aa3cfd4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4a37b8a446de7dff1c61f08aa3cfd4b.addTo(map_aede565fe4ca001472116df3dff3dbec);
#
#
#             map_aede565fe4ca001472116df3dff3dbec.fitBounds(
#                 [[29.044931, -96.907489], [39.420938, -76.018317]],
#                 {}
#             );
#
#
#         function geo_json_6ff2483ed4b84b514081326eb014c6f3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6ff2483ed4b84b514081326eb014c6f3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6ff2483ed4b84b514081326eb014c6f3_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6ff2483ed4b84b514081326eb014c6f3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6ff2483ed4b84b514081326eb014c6f3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6ff2483ed4b84b514081326eb014c6f3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6ff2483ed4b84b514081326eb014c6f3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6ff2483ed4b84b514081326eb014c6f3 = L.geoJson(null, {
#                 onEachFeature: geo_json_6ff2483ed4b84b514081326eb014c6f3_onEachFeature,
#
#                 style: geo_json_6ff2483ed4b84b514081326eb014c6f3_styler,
#                 pointToLayer: geo_json_6ff2483ed4b84b514081326eb014c6f3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6ff2483ed4b84b514081326eb014c6f3_add (data) {
#             geo_json_6ff2483ed4b84b514081326eb014c6f3
#                 .addData(data);
#         }
#             geo_json_6ff2483ed4b84b514081326eb014c6f3_add({&quot;bbox&quot;: [-96.907489, 29.044931, -76.018317, 39.420938], &quot;features&quot;: [{&quot;bbox&quot;: [-95.389135, 34.95654, -95.389135, 34.95654], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.389135, 34.95654], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Pantherophis guttatus&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;deci

# %% [markdown]
# ## 17. Combine the three GeoDataFrames
#
# Use `pd.concat()` to combine your three species GeoDataFrames.
#
# Then inspect the first few rows.

# %%
gbif_snakes = pd.concat([contortrix_gdf, dekayi_gdf, Pantherophis_gdf])

gbif_snakes.head()
# Out:
#           key                           scientificName  decimalLongitude  \
# 0  5938040489  Agkistrodon contortrix (Linnaeus, 1766)        -95.389135
# 1  5938333386  Agkistrodon contortrix (Linnaeus, 1766)        -96.749162
# 2  6130329629  Agkistrodon contortrix (Linnaeus, 1766)        -92.049384
# 3  6130508356  Agkistrodon contortrix (Linnaeus, 1766)        -96.084503
# 4  6131231662  Agkistrodon contortrix (Linnaeus, 1766)        -92.068888
#
#    decimalLatitude  year      basisOfRecord countryCode  \
# 0        34.956540  2026  HUMAN_OBSERVATION          US
# 1        32.874482  2026  HUMAN_OBSERVATION          US
# 2        29.898102  2026  HUMAN_OBSERVATION          US
# 3        30.170800  2026  HUMAN_OBSERVATION          US
# 4        29.979926  2026  HUMAN_OBSERVATION          US
#
#                      geometry                 Species
# 0  POINT (-95.38914 34.95654)  Agkistrodon contortrix
# 1  POINT (-96.74916 32.87448)  Agkistrodon contortrix
# 2   POINT (-92.04938 29.8981)  Agkistrodon contortrix
# 3    POINT (-96.0845 30.1708)  Agkistrodon contortrix
# 4  POINT (-92.06889 29.97993)  Agkistrodon contortrix

# %% [markdown]
# ## 18. Map all three species together
#
# Use `.explore()` and color by `Species` so you can compare the three species on one map.

# %%
gbif_snakes.explore(column="Species", cmap="rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4aa8f2a632f550492cc7e4e4783b1610 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8000ff&#x27;&gt;&lt;/span&gt;Agkistrodon contortrix&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#80ffb4&#x27;&gt;&lt;/span&gt;Pantherophis guttatus&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Storeria dekayi&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4aa8f2a632f550492cc7e4e4783b1610&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4aa8f2a632f550492cc7e4e4783b1610 = L.map(
#                 &quot;map_4aa8f2a632f550492cc7e4e4783b1610&quot;,
#                 {
#                     center: [33.9734105, -86.7033295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4aa8f2a632f550492cc7e4e4783b1610);
#
#
#
#
#
#             var tile_layer_1346f9e79701653e0539c80fa8134d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1346f9e79701653e0539c80fa8134d71.addTo(map_4aa8f2a632f550492cc7e4e4783b1610);
#
#
#             map_4aa8f2a632f550492cc7e4e4783b1610.fitBounds(
#                 [[25.771463, -98.225659], [42.175358, -75.181]],
#                 {}
#             );
#
#
#         function geo_json_461a18911818713e76008f63cdaad3a0_styler(feature) {
#             switch(feature.properties.key) {
#                 case 5938040489: case 5938333386: case 6130329629: case 6130508356: case 6131231662: case 6147344325: case 6147620548: case 6159144996: case 6159231126: case 6159335829: case 6159349505: case 6159435465: case 6159438688: case 6159469389: case 6159471187: case 6159548165: case 6159603953: case 6159686615: case 6162780251: case 6162837854: case 6162846680: case 6162855353: case 6162862226: case 6162925641: case 6162953649: case 6163045007: case 6163056036: case 6163377444: case 6170967411: case 6170976197: case 6171007298: case 6171082884: case 6171131953: case 6171430109: case 6178548358: case 6179185702

# %% [markdown]
# ## 19. Count records by species
#
# Use `groupby()` to count how many records you downloaded for each species.

# %%
gbif_snakes.groupby("Species").size()
# Out:
# Species
# Agkistrodon contortrix    100
# Pantherophis guttatus     100
# Storeria dekayi           100
# dtype: int64

# %% [markdown]
# ## 20. Count records by basis of record
#
# The `countryCode` field describes the general type of occurrence record.
#
# Use `groupby()` to count records by `countryCode`.

# %%
gbif_snakes.groupby("countryCode").size()
# Out:
# countryCode
# MX      2
# US    298
# dtype: int64

# %% [markdown]
# ## 21. Choose one additional species
#
# Choose one additional snake species and repeat the workflow.
#
# Your species does not have to be in the local `EasternSnakes` CSV files. It only needs to be a snake species that GBIF can find.
#
# Your code should:
#
# * use `species.name_suggest()`
# * save the taxon key
# * count georeferenced records
# * fetch no more than 100 records with `occ.search()`
# * convert the records to a `GeoDataFrame`
# * map the records

# %%
# Write your code here.
sipedon_suggestions = species.name_suggest(q="Nerodia sipedon")
sipedon_suggestions
# Select the first element from the `contortrix_suggestions` list
sipedon_match = sipedon_suggestions[0]
# Get the `speciesKey`
sipedon_key = sipedon_match["speciesKey"]

sipedon_key

sipedon_records = occ.search(
    speciesKey= sipedon_key,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)
sipedon_df = pd.DataFrame(sipedon_records["results"])
sipedon_small = sipedon_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]]

sipedon_gdf = gpd.GeoDataFrame(
    sipedon_small,
    geometry=gpd.points_from_xy(contortrix_small["decimalLongitude"], contortrix_small["decimalLatitude"]),
    crs="EPSG:4326",
)
sipedon_gdf["Species"] = "Nerodia sipedon"

sipedon_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0794ded9783a75b3d7027ea0c3475ae9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0794ded9783a75b3d7027ea0c3475ae9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0794ded9783a75b3d7027ea0c3475ae9 = L.map(
#                 &quot;map_0794ded9783a75b3d7027ea0c3475ae9&quot;,
#                 {
#                     center: [34.2329345, -86.462903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0794ded9783a75b3d7027ea0c3475ae9);
#
#
#
#
#
#             var tile_layer_6e8bf8d9a91edd0193fb21ae119c2c39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e8bf8d9a91edd0193fb21ae119c2c39.addTo(map_0794ded9783a75b3d7027ea0c3475ae9);
#
#
#             map_0794ded9783a75b3d7027ea0c3475ae9.fitBounds(
#                 [[29.044931, -96.907489], [39.420938, -76.018317]],
#                 {}
#             );
#
#
#         function geo_json_7ceb39009ebe0c288cb64583def2ca4e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7ceb39009ebe0c288cb64583def2ca4e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7ceb39009ebe0c288cb64583def2ca4e_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_7ceb39009ebe0c288cb64583def2ca4e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7ceb39009ebe0c288cb64583def2ca4e_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_7ceb39009ebe0c288cb64583def2ca4e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7ceb39009ebe0c288cb64583def2ca4e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7ceb39009ebe0c288cb64583def2ca4e = L.geoJson(null, {
#                 onEachFeature: geo_json_7ceb39009ebe0c288cb64583def2ca4e_onEachFeature,
#
#                 style: geo_json_7ceb39009ebe0c288cb64583def2ca4e_styler,
#                 pointToLayer: geo_json_7ceb39009ebe0c288cb64583def2ca4e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_7ceb39009ebe0c288cb64583def2ca4e_add (data) {
#             geo_json_7ceb39009ebe0c288cb64583def2ca4e
#                 .addData(data);
#         }
#             geo_json_7ceb39009ebe0c288cb64583def2ca4e_add({&quot;bbox&quot;: [-96.907489, 29.044931, -76.018317, 39.420938], &quot;features&quot;: [{&quot;bbox&quot;: [-95.389135, 34.95654, -95.389135, 34.95654], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.389135, 34.95654], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Nerodia sipedon&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;decimalLat

# %%
print(dekayi_key,
contortrix_key,
Pantherophis_key)
# Out:
# 9056579 9215881 2455615

# %% [markdown]
# ## 22. Written reflection
#
# Answer these questions after running your code.
#
# **Question 1:** Which of your species had the most GBIF records available?
#
# **Your answer:** Agkistrodon contortrix
#
# **Question 2:** Did the GBIF points look similar to the local CSV points from Assignment 01? Why might GBIF records look different?
#
# **Your answer:** The points look similar, but the GBIF records are more detailed and there are far more of them per species compared to the number of records per species in assignment 1. I assume this is becuase GBIF requires additional information to be uploaded along with the coordinates and species name, and the number of people using GBIF leads to such a large amount of data being avilable.
#
# **Question 3:** What is one reason it is useful to count records before downloading or mapping them?
#
# **Your answer:** If you have a large number of records it may be too computational intense. ALso if you need a similar number of records per species in your analysis, it is helpful to know how many records are avilable for each species.

# %% [markdown]
# ## 23. Submit your work
#
# Before submitting, make sure you have run the notebook from top to bottom and answered the written questions.
#
# Commit and push your completed notebook to your class GitHub repository.
#
# Open a terminal window and run these commands to add, commit, and push your notebook:
#
# ```
# # Go to the labs directory in the course repo
# cd ~/BIO597-SpatialBiodiversity/docs/assignments
#
# # Add your changed lab
# git add Assignment-02-pygbif.ipynb
# git commit -m 'Finished Assignment 02'
# git push
# ```
